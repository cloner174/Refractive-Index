# %%
from Light import TwoLayerObject

# %%
test = TwoLayerObject( n0= 1, nt= 1, na = 1, nb = 1.1 , landa0= 1500)

# %%
test.show_plot( first = 1, final = 3000, step = 1 )

# %%
test.show_plot( first = 1, final = 500, step = 11 )

# %%
TwoLayerObject( n0= 1, nt= 1, na = 1, nb = 2 , landa0= 800).show_plot( first = 1, final = 1500, step = 0.5 )
