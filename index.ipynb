# %%
from Light import OneLayerObject

# %%
test = OneLayerObject()

# %%
test.show_plot( first = 1, final = 500, step = 0.5, figure_size = (10, 5), show_Transmission = False, show_Reflection = True)

# %%
test.show_plot( first = 1, final = 500, step = 0.5, figure_size = (10, 5), show_Transmission = True, show_Reflection = False)
